# %% [markdown]
# second program to check git push functionality

# %%
from pyspark.sql import SparkSession
df = spark.table("samples.bakehouse.sales_customers")

df.display(10)

# %%
df1 = df.filter(df.gender == "female")
df1.display(10)
df2 = df.filter(df.customerID == "2000259")
df2.display(10)

# %%
# %fs
ls

# %%
df1.write.mode("overwrite")\
    .save("/Volumes/workspace/default/dbfs_replacement/female.csv")
